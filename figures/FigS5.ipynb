# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_rdf(filename):
    x, *rdfs = np.loadtxt(filename).T
    names = ('all', 'no_h', 'o', 'no_o')
    return x, {name: rdf for name, rdf in zip(names, rdfs)}

# %%
x, qm = read_rdf('CHO/RDF/qm.rdf')
x, emle = read_rdf('CHO/RDF/emle.rdf')
x, qm_h2o = read_rdf('CHO/RDF/qm_h2o.rdf')

# %%
name = 'no_h'

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, qm[name], label='QM/MM (Cho)')
ax.plot(x, emle[name], label='ML(EMLE)/MM')
ax.plot(x, qm_h2o[name], label='QM/MM (Cho+H$_2$O)')
ax.set_xlabel('Distance ($\\AA$)')
ax.set_ylabel('Density')
ax.set_xlim([2,4])
ax.axvline(2.77, c='grey', lw=1)
ax.legend(loc='lower right')
plt.savefig('FigS5.png', dpi=300, bbox_inches='tight')
plt.show()
